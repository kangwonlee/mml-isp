# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# ## $R^2$

# %%
x = np.linspace(-1, 1)

# %%
X, Y = np.meshgrid(x, x)

# %% [markdown]
# ## Function

# %%
def plot_norm(p):
    norm = (np.abs(X)**p+np.abs(Y)**p)**(1.0/p)

    plt.clf()
    plt.contour(X, Y, norm)
    plt.colorbar()
    plt.axis('equal')
    plt.title('$\\Vert \\mathbf{x} \\Vert_{' + str(p) + '}$') # https://matplotlib.org/3.1.1/tutorials/text/mathtext.html
    plt.savefig('norm-%s.png' % (str(p).replace('.', '_')))

# %%
for p in np.arange(2, 0, -0.25):
    plot_norm(p)
    plt.show()
